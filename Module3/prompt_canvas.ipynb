# %% [markdown]
# ### We can open prompt camnvas by clciking on this magic wand tool in the playground :
# ![image.png](attachment:bdf0bf79-b4af-4740-9aec-1a3356c02c1f.png)

# %% [markdown]
# ### Prompt canvas interface :
# ![image.png](attachment:ba667157-5040-4df1-a46a-713e5b0f7e59.png)

# %% [markdown]
# ### I asked it to give my chatbot the persona of a pirate
# ![image.png](attachment:6e22c517-e7f6-4082-b36f-b8ed00353092.png)

# %% [markdown]
# ### we can click on this button to directly add the prompt the llm just wrote
#
# ![image.png](attachment:4ad93341-404c-4ff0-91cc-92f9ff7b1a84.png)

# %% [markdown]
# ### Using diff we can see the difference between our last prompt and the current fabricated prompt
#
# ![image.png](attachment:e97d487c-0279-4f18-8b2c-4577dbaba11c.png)

# %% [markdown]
# ### We can even ask it for suggestions and feedback on the prompt to further improve it
#
# ![image.png](attachment:66f195ee-dbd4-4c99-8220-590d04c23cc9.png)

# %% [markdown]
# ### We can also type in extra details like in this example i have typed in how this pirat fought a huge kraken
# ![image.png](attachment:045947c7-05da-4ed5-87d3-d1818ed8a226.png)

# %% [markdown]
# ### this is what we can see in the playground when we click on "use this version" and then ask our llm a question
#
#
# ![image.png](attachment:69fe5fa8-3280-496c-bc8c-07a6e1b6c58b.png)

# %% [markdown]
# ### we can also choose to make the llm edit only a specific part of our code like this :
#
#
#
#
# ![image.png](attachment:86541e84-be2a-4c78-88fb-1a3a14ead15b.png)

# %% [markdown]
# ### Using the quick action button we can standardise out prompts, for ex I have taken the reading level quick action :
#
# ![image.png](attachment:ef554ca5-d0d4-4724-a159-8e0c1377cc00.png)

# %% [markdown]
# ### There's also a quick option which can set the length of the prompt :
# ![image.png](attachment:e6a7206d-67e9-4159-9f98-bc513796048d.png)

# %% [markdown]
# ### here in this examples I have asked it to increase the reading level and shorten the length of the prompt:
#
# ![image.png](attachment:bb79ea61-784d-4cfe-be7f-aca400c2761c.png)

# %% [markdown]
# ### We can aso add our own custom actions using this button in the prompt canvas :
#
# ![image.png](attachment:ba3ce128-a622-45ce-ae3f-3af2a7d3ec50.png)

# %% [markdown]
# ### Another example where i asked the llm to write a prompt for an llm which gives food recommendation based on mood, I have set the reading level at easy and the prompt length to high :
#
# ![image.png](attachment:8c84d299-3a48-4efd-b9d0-44586f8a579e.png)

# %% [markdown]
# ### We can see that the llm gives the output based on this prompt which we formulated using the prompt canvas :
# ![image.png](attachment:4a1f4eca-a0ee-449d-82a9-a31ddfb7b0cd.png)
